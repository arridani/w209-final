# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
from tqdm import tqdm
plt.style.use('ggplot')

# %%
df = pd.read_csv('../data/statcast_04_04_2022_10_03_2022.csv')
df.columns
# Out:
# Index(['pitch_type', 'game_date', 'release_speed', 'release_pos_x',
#        'release_pos_z', 'player_name', 'batter', 'pitcher', 'events',
#        'description', 'spin_dir', 'spin_rate_deprecated',
#        'break_angle_deprecated', 'break_length_deprecated', 'zone', 'des',
#        'game_type', 'stand', 'p_throws', 'home_team', 'away_team', 'type',
#        'hit_location', 'bb_type', 'balls', 'strikes', 'game_year', 'pfx_x',
#        'pfx_z', 'plate_x', 'plate_z', 'on_3b', 'on_2b', 'on_1b',
#        'outs_when_up', 'inning', 'inning_topbot', 'hc_x', 'hc_y',
#        'tfs_deprecated', 'tfs_zulu_deprecated', 'fielder_2', 'umpire', 'sv_id',
#        'vx0', 'vy0', 'vz0', 'ax', 'ay', 'az', 'sz_top', 'sz_bot',
#        'hit_distance_sc', 'launch_speed', 'launch_angle', 'effective_speed',
#        'release_spin_rate', 'release_extension', 'game_pk', 'pitcher.1',
#        'fielder_2.1', 'fielder_3', 'fielder_4', 'fielder_5', 'fielder_6',
#        'fielder_7', 'fielder_8', 'fielder_9', 'release_pos_y',
#        'estimated_ba_using_speedangle', 'estimated_woba_using_speedangle',
#        'woba_value', 'woba_denom', 'babip_value', 'iso_value',
#        'launch_speed_angle', 'at_bat_number', 'pitch_number', 'pitch_name',
#        'home_score', 'away_score', 'bat_score', 'fld_score', 'post_away_score',
#        'post_home_score', 'post_bat_score', 'post_fld_score',
#        'if_fielding_alignment', 'of_fielding_alignment', 'spin_axis',
#        'delta_home_win_exp', 'delta_run_exp'],
#       dtype='object')

# %%
# filter columns
columns = ['game_date',
#            'player_name', 'batter', 'pitcher',
#        'stand', 'p_throws', 'home_team', 'away_team', 
           'release_speed',
       'outs_when_up',
#            'inning', 'inning_topbot',
           'pitch_name',
       'home_score', 'away_score']
filtered = df[columns]
filtered['game_date'] = pd.to_datetime(filtered.game_date)
print(filtered.columns)
# filtered.to_csv('../data/hypothesis_4.csv')
# filtered
df.groupby(['outs_when_up', 'pitch_name']).count()['pitch_type'].reset_index()
df.groupby(['outs_when_up', 'pitch_name']).mean()['release_speed'].reset_index()
# Out:
# /Users/dimitriospsaltos/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# Index(['game_date', 'release_speed', 'outs_when_up', 'pitch_name',
#        'home_score', 'away_score'],
#       dtype='object')
#     outs_when_up       pitch_name  release_speed
# 0              0  4-Seam Fastball      93.659889
# 1              0         Changeup      85.072937
# 2              0        Curveball      78.765390
# 3              0           Cutter      88.824681
# 4              0           Eephus      49.960510
# 5              0         Fastball      67.567529
# 6              0    Knuckle Curve      80.884676
# 7              0      Knuckleball      53.520000
# 8              0           Sinker      93.077581
# 9              0           Slider      84.424842
# 10             0     Split-Finger      86.965656
# 11             1  4-Seam Fastball      94.002318
# 12             1         Changeup      85.425367
# 13             1        Curveball      79.096790
# 14             1           Cutter      89.003588
# 15             1           Eephus      49.244138
# 16             1         Fastball      68.023000
# 17             1    Knuckle Curve      81.355772
# 18             1      Knuckleball      55.700000
# 19             1           Sinker      93.426144
# 20             1           Slider      84.646964
# 21             1     Split-Finger      87.346737
# 22             2  4-Seam Fastball      94.141130
# 23             2         Changeup      85.516188
# 24             2        Curveball      79.308794
# 25             2           Cutter      89.176117
# 26             2           Eephus      50.808511
# 27             2         Fastball      69.237188
# 28             2    Knuckle Curve      81.465772
# 29             2      Knuckleball      56.357143
# 30             2           Sinker      93.578088
# 31             2           Slider      84.697916
# 32             2     Split-Finger      87.284409

# %%
# new_filter = filtered.groupby(['game_date', 'pitch_name', 'outs_when_up']).count()['home_score'].reset_index()
new_filter = filtered.groupby(['game_date', 'pitch_name', 'outs_when_up']).agg({'home_score': 'count',
                                                                   'release_speed': 'mean'}).reset_index()
new_filter.columns = ['game_date', 'pitch_type', 'outs_when_up', 'n_pitches',
                     'mean_pitch_speed']
new_filter.to_csv('../data/hypothesis_4.csv')
new_filter
# Out:
#       game_date       pitch_type  outs_when_up  n_pitches  mean_pitch_speed
# 0    2022-04-07  4-Seam Fastball             0        248         93.647177
# 1    2022-04-07  4-Seam Fastball             1        176         93.936364
# 2    2022-04-07  4-Seam Fastball             2        235         93.767660
# 3    2022-04-07         Changeup             0         73         84.452055
# 4    2022-04-07         Changeup             1         75         84.033333
# ...         ...              ...           ...        ...               ...
# 4499 2022-10-02           Slider             1        312         84.392628
# 4500 2022-10-02           Slider             2        316         84.294620
# 4501 2022-10-02     Split-Finger             0         19         85.952632
# 4502 2022-10-02     Split-Finger             1         22         85.327273
# 4503 2022-10-02     Split-Finger             2         14         84.542857
#
# [4504 rows x 5 columns]

# %%
filtered.groupby(['game_date', 'pitch_name', 'outs_when_up']).agg({'home_score': 'count',
                                                                   'release_speed': 'mean'}).reset_index()
# Out:
#       game_date       pitch_name  outs_when_up  home_score  release_speed
# 0    2022-04-07  4-Seam Fastball             0         248      93.647177
# 1    2022-04-07  4-Seam Fastball             1         176      93.936364
# 2    2022-04-07  4-Seam Fastball             2         235      93.767660
# 3    2022-04-07         Changeup             0          73      84.452055
# 4    2022-04-07         Changeup             1          75      84.033333
# ...         ...              ...           ...         ...            ...
# 4499 2022-10-02           Slider             1         312      84.392628
# 4500 2022-10-02           Slider             2         316      84.294620
# 4501 2022-10-02     Split-Finger             0          19      85.952632
# 4502 2022-10-02     Split-Finger             1          22      85.327273
# 4503 2022-10-02     Split-Finger             2          14      84.542857
#
# [4504 rows x 5 columns]

# %% [markdown]
# filtered.groupby

# %%
df.head()
# Out:
#   pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 0         FF  2022-10-02           93.5           1.70           5.95
# 1         CU  2022-10-02           80.9           2.06           5.59
# 2         FF  2022-10-02           92.3           1.65           5.93
# 3         FF  2022-10-02           94.3           1.65           5.93
# 4         FF  2022-10-02           93.4           1.81           5.93
#
#       player_name  batter  pitcher     events    description  ...  fld_score  \
# 0  Zastryzny, Rob  663993   642239  strikeout       foul_tip  ...          8
# 1  Zastryzny, Rob  663993   642239        NaN           ball  ...          8
# 2  Zastryzny, Rob  663993   642239        NaN           foul  ...          8
# 3  Zastryzny, Rob  663993   642239        NaN           ball  ...          8
# 4  Zastryzny, Rob  663993   642239        NaN  called_strike  ...          8
#
#    post_away_score  post_home_score  post_bat_score  post_fld_score  \
# 0                3                8               3               8
# 1                3                8               3               8
# 2                3                8               3               8
# 3                3                8               3               8
# 4                3                8               3               8
#
#   if_fielding_alignment of_fielding_alignment spin_axis delta_home_win_exp  \
# 0              Standard              Standard     167.0                0.0
# 1              Standard              Standard     273.0                0.0
# 2              Standard              Standard     157.0                0.0
# 3              Standard              Standard     159.0                0.0
# 4              Standard              Standard     156.0                0.0
#
#   delta_run_exp
# 0        -0.084
# 1         0.014
# 2         0.000
# 3         0.011
# 4        -0.023
#
# [5 rows x 92 columns]

# %%
starting_pitchers = []
for g in tqdm(df.game_pk.unique()):#g in tqdm(df.game_date.unique()):
    sub_df = df[(df.game_pk == g) & (df.inning==1)]
#     for ht in sub1.home_team.unique():
#         for at in sub1.away_team.unique():
#             sub_df = df[(df.game_date == g) &
#                        (df.home_team == ht) &
#                        (df.away_team == at) &
#                        (df.inning == 1)]
    if sub_df.empty: continue
    home_pitcher = sub_df[sub_df.inning_topbot == 'Top'].player_name.unique()
    away_pitcher = sub_df[sub_df.inning_topbot == 'Bot'].player_name.unique()
    if len(home_pitcher) == len(away_pitcher):
        for i in range(len(home_pitcher)):
            home_pitcher_pitches = df[(df.game_date == g) &
                       (df.home_team == ht) &
                       (df.away_team == at) &
                       (df.player_name == home_pitcher[i])].shape[0]
            away_pitcher_pitches = df[(df.game_date == g) &
                       (df.home_team == ht) &
                       (df.away_team == at) &
                       (df.player_name == away_pitcher[i])].shape[0]
            obj = {'game_date': g,
                  'home_team': ht,
                  'away_team': at,
                  'home_pitcher': home_pitcher[i],
                  'away_pitcher': away_pitcher[i],
                  'home_pitcher_pitches': home_pitcher_pitches,
                  'away_pitcher_pitches': away_pitcher_pitches}
            starting_pitchers.append(obj)
    elif len(home_pitcher) > len(away_pitcher):
        for i in range(len(away_pitcher)):
            home_pitcher_pitches = df[(df.game_date == g) &
                       (df.home_team == ht) &
                       (df.away_team == at) &
                       (df.player_name == home_pitcher[i])].shape[0]
            away_pitcher_pitches = df[(df.game_date == g) &
                       (df.home_team == ht) &
                       (df.away_team == at) &
                       (df.player_name == away_pitcher[i])].shape[0]
            obj = {'game_date': g,
                  'home_team': ht,
                  'away_team': at,
                  'home_pitcher': home_pitcher[i],
                  'away_pitcher': away_pitcher[i],
                  'home_pitcher_pitches': home_pitcher_pitches,
                  'away_pitcher_pitches': away_pitcher_pitches}
            starting_pitchers.append(obj)
    elif len(home_pitcher) < len(away_pitcher):
        for i in range(len(home_pitcher)):
            home_pitcher_pitches = df[(df.game_date == g) &
                       (df.home_team == ht) &
                       (df.away_team == at) &
                       (df.player_name == home_pitcher[i])].shape[0]
            away_pitcher_pitches = df[(df.game_date == g) &
                       (df.home_team == ht) &
                       (df.away_team == at) &
                       (df.player_name == away_pitcher[i])].shape[0]
            obj = {'game_date': g,
                  'home_team': ht,
                  'away_team': at,
                  'home_pitcher': home_pitcher[i],
                  'away_pitcher': away_pitcher[i],
                  'home_pitcher_pitches': home_pitcher_pitches,
                  'away_pitcher_pitches': away_pitcher_pitches}
            starting_pitchers.append(obj)
    else:
        raise ValueError

# starting_pitchers[['game_date', 'release_speed', 'player_name', 'pitcher', 
#        'p_throws', 'home_team', 'away_team',
#        'outs_when_up', 'inning', 'inning_topbot', 'pitch_number', 'pitch_name',
#        'home_score', 'away_score', 'bat_score', 'fld_score', 'post_away_score',
#        'post_home_score', 'post_bat_score', 'post_fld_score',
#        'if_fielding_alignment', 'of_fielding_alignment', 'spin_axis',
#        'delta_home_win_exp', 'delta_run_exp']]
#
#   4%|▍         | 90/2383 [11:41<6:11:25,  9.72s/it]
#
#   4%|▍         | 91/2383 [11:52<6:25:49, 10.10s/it]
#
#   4%|▍         | 92/2383 [12:02<6:24:11, 10.06s/it]
#
#   4%|▍         | 93/2383 [12:10<6:06:31,  9.60s/it]
#
#   4%|▍         | 94/2383 [12:19<6:00:10,  9.44s/it]
#
#   4%|▍         | 95/2383 [12:28<5:55:31,  9.32s/it]
#
#   4%|▍         | 96/2383 [12:37<5:48:55,  9.15s/it]
#
#   4%|▍         | 97/2383 [12:46<5:42:26,  8.99s/it]
#
#   4%|▍         | 98/2383 [12:54<5:31:56,  8.72s/it]
#
#   4%|▍         | 99/2383 [13:02<5:22:31,  8.47s/it]
#
#   4%|▍         | 100/2383 [13:09<5:12:35,  8.22s/it]
#
#   4%|▍         | 101/2383 [13:18<5:13:26,  8.24s/it]
#
#   4%|▍         | 102/2383 [13:28<5:32:49,  8.75s/it]
#
#   4%|▍         | 103/2383 [13:37<5:45:44,  9.10s/it]
#
#   4%|▍         | 104/2383 [13:45<5:28:19,  8.64s/it]
#
#   4%|▍         | 105/2383 [13:52<5:08:53,  8.14s/it]
#
#   4%|▍         | 106/2383 [13:59<4:55:38,  7.79s/it]
#
#   4%|▍         | 107/2383 [14:06<4:51:21,  7.68s/it]
#
#   5%|▍         | 108/2383 [14:16<5:16:32,  8.35s/it]
#
#   5%|▍         | 109/2383 [14:24<5:14:08,  8.29s/it]
#
#   5%|▍         | 110/2383 [14:32<5:07:18,  8.11s/it]
#
#   5%|▍         | 111/2383 [14:40<5:01:16,  7.96s/it]
#
#   5%|▍         | 112/2383 [14:47<4:52:43,  7.73s/it]
#
#   5%|▍         | 113/2383 [14:54<4:42:47,  7.47s/it]
#
#   5%|▍         | 114/2383 [15:01<4:35:45,  7.29s/it]
#
#   5%|▍         | 115/2383 [15:09<4:42:47,  7.48s/it]
#
#   5%|▍         | 116/2383 [15:17<4:58:17,  7.89s/it]
#
#   5%|▍         | 117/2383 [15:26<5:01:31,  7.98s/it]
#
#   5%|▍         | 118/2383 [15:34<5:01:34,  7.99s/it]
#
#   5%|▍         | 119/2383 [15:42<5:00:21,  7.96s/it]
#
#   5%|▌         | 120/2383 [15:50<5:04:13,  8.07s/it]
#
#   5%|▌         | 121/2383 [16:00<5:24:28,  8.61s/it]
#
#   5%|▌         | 122/2383 [16:08<5:16:35,  8.40s/it]
#
#   5%|▌         | 123/2383 [16:16<5:13:36,  8.33s/it]
#
#   5%|▌         | 124/2383 [16:24<5:14:56,  8.36s/it]
#
#   5%|▌         | 125/2383 [16:35<5:47:01,  9.22s/it]
#
#   5%|▌         | 126/2383 [16:44<5:38:00,  8.99s/it]
#
#   5%|▌         | 127/2383 [16:51<5:17:22,  8.44s/it]
#
#   5%|▌         | 128/2383 [16:58<5:00:37,  8.00s/it]
#
#   5%|▌         | 129/2383 [17:07<5:14:00,  8.36s/it]
#
#   5%|▌         | 130/2383 [17:17<5:32:57,  8.87s/it]
#
#   5%|▌         | 131/2383 [17:26<5:32:53,  8.87s/it]
#
#   6%|▌         | 132/2383 [17:34<5:25:57,  8.69s/it]

# %%
pd.DataFrame(starting_pitchers)
# Out:
# Empty DataFrame
# Columns: []
# Index: []
